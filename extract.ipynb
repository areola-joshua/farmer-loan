# %%
import pandas as pd
import pyreadstat

df, meta = pyreadstat.read_sav("FarmingHouseholds_ano.sav")
df.head()
# Out:
#       HHID  state_code  lga_code  ea_code  zone_id  sector  hh_sex  hh_age  \
# 0  0676419        31.0       NaN  0038900      4.0     1.0     2.0     4.0
# 1  0200985        31.0     639.0  0038900      4.0     1.0     1.0     4.0
# 2  0322518        31.0     639.0  0038900      4.0     1.0     1.0     5.0
# 3  0037878        31.0     639.0  0038900      4.0     1.0     2.0     6.0
# 4  0448913        31.0     639.0  0038900      4.0     1.0     1.0     5.0
#
#    hh_school_attd  hh_edu_level  ...  agri_estab_kind__3  non_agri_estab  \
# 0             1.0           2.0  ...                 NaN             2.0
# 1             1.0           4.0  ...                 NaN             1.0
# 2             1.0           5.0  ...                 NaN             1.0
# 3             1.0           4.0  ...                 NaN             1.0
# 4             1.0           4.0  ...                 NaN             1.0
#
# ...

# %%
pip install pyreadstat
# Out:
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 541.6 kB/s eta 0:00:04
#    -------- ------------------------------- 0.5/2.4 MB 541.6 kB/s eta 0:00:04
#    ------------- -------------------------- 0.8/2.4 MB 578.7 kB/s eta 0:00:03
#    ------------- -------------------------- 0.8/2.4 MB 578.7 kB/s eta 0:00:03
#    ----------------- ---------------------- 1.0/2.4 MB 592.2 kB/s eta 0:00:03
#    ----------------- ---------------------- 1.0/2.4 MB 592.2 kB/s eta 0:00:03
#    --------------------- ------------------ 1.3/2.4 MB 633.2 kB/s eta 0:00:02
# ...

# %%
df.columns
# Out:
# Index(['HHID', 'state_code', 'lga_code', 'ea_code', 'zone_id', 'sector',
#        'hh_sex', 'hh_age', 'hh_school_attd', 'hh_edu_level',
#        ...
#        'agri_estab_kind__3', 'non_agri_estab', 'non_agri_estab_kind__1',
#        'non_agri_estab_kind__2', 'non_agri_estab_kind__3',
#        'non_agri_estab_kind__4', 'non_agri_estab_kind__5',
#        'non_agri_estab_kind__6', 'non_agri_estab_kind__999',
#        'nasc_listing_weight'],
#       dtype='object', length=137)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002380 entries, 0 to 1002379
# Columns: 137 entries, HHID to nasc_listing_weight
# dtypes: float64(134), object(3)
# memory usage: 1.0+ GB

# %%
df.columns.tolist()
# Out:
# ['HHID',
#  'state_code',
#  'lga_code',
#  'ea_code',
#  'zone_id',
#  'sector',
#  'hh_sex',
#  'hh_age',
#  'hh_school_attd',
#  'hh_edu_level',
#  'hh_trg',
#  'hh_trg_type__1',
#  'hh_trg_type__2',
#  'hh_ag_activity__Crop',
#  'hh_ag_activity__Livestock',
#  'hh_ag_activity__Poultry',
#  'hh_ag_activity__Fisheries',
#  'hh_ag_activity__Forestry',
#  'hh_plots_number',
#  'hh_cereals__MAIZE',
#  'hh_cereals__RICE',
#  'hh_cereals__MILLET',
#  'hh_cereals__GUINEA_CORN',
#  'hh_cereals__ACHA',
#  'hh_cereals__WHEAT',
#  'hh_cereals__NONE',
#  'hh_tubers__CASSAVA',
#  'hh_tubers__YAM',
#  'hh_tubers__COCOYAM',
#  'hh_tubers__SWEET_POTATO',
#  'hh_tubers__IRISH_POTATO',
#  'hh_tubers__NONE',
#  'hh_legumes__BEANS_COWPEA',
#  'hh_legumes__BAMBARA_NUT',
#  'hh_legumes__PIGEON_PEAS',
#  'hh_legumes__NONE',
#  'hh_vegetables__ONION',
#  'hh_vegetables__OKRO',
#  'hh_vegetables__TOMATOES',
#  'hh_vegetables__CARROT',
#  'hh_vegetables__GARLIC',
#  'hh_vegetables__GREEN_LEAF',
# ...

# %%
df.to_csv("FarmingHouseholds_ano.csv", index=False)

# %%
df = pd.read_csv("FarmingHouseholds_ano.csv")

# Sample 30% of each state group
df_sampled = (
    df.groupby('state_code', group_keys=False)
    .apply(lambda x: x.sample(frac=0.3, random_state=42))
)

df_sampled.to_csv("FarmingHouseholds_30percent_sampled.csv", index=False)
# Out:
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_7896\3683380409.py:2: DtypeWarning: Columns (107) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("FarmingHouseholds_ano.csv")
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_7896\3683380409.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(frac=0.3, random_state=42))

# %%
columns_to_keep = {
    'HHID': 'household_id',
    'state_code': 'state',
    'lga_code': 'lga',
    'hh_sex': 'hh_head_sex',
    'hh_age': 'hh_head_age',
    'hh_school_attd': 'school_attendance',
    'hh_edu_level': 'education_level',
    'hh_ag_activity__Crop': 'activity_crop',
    'hh_ag_activity__Livestock': 'activity_livestock',
    'hh_ag_activity__Poultry': 'activity_poultry',
    'hh_ag_activity__Fisheries': 'activity_fisheries',
    'hh_plots_number': 'num_plots',
    'hh_cereals__MAIZE': 'grow_maize',
    'hh_cereals__RICE': 'grow_rice',
    'hh_legumes__BEANS_COWPEA': 'grow_beans',
    'hh_tot_number__CATTLE': 'num_cattle',
    'hh_tot_number__GOAT': 'num_goat',
    'hh_tot_number__CHICKEN': 'num_chicken',
    'hh_fisheries_list__FISH_FARMING': 'fish_farming',
    'agri_estab': 'has_agri_establishment',
    'non_agri_estab': 'has_nonagri_establishment',
    'nasc_listing_weight': 'weight'
}

# %%
df_filtered = df_sampled[list(columns_to_keep.keys())].rename(columns=columns_to_keep)

df_filtered.to_csv("FarmingHouseholds_filtered_renamed.csv", index=False)

# %%
df_filtered.head()
# Out:
#         household_id  state   lga  hh_head_sex  hh_head_age  \
# 926732        966601    1.0  16.0          1.0          5.0
# 907051        189961    1.0  18.0          1.0          3.0
# 926516        130859    1.0  16.0          1.0          3.0
# 912760        655320    1.0   1.0          1.0          5.0
# 910795        440860    1.0   9.0          1.0          4.0
#
#         school_attendance  education_level  activity_crop  activity_livestock  \
# 926732                2.0              NaN            2.0                 2.0
# 907051                1.0              5.0            2.0                 2.0
# 926516                1.0              6.0            2.0                 2.0
# 912760                2.0              NaN            2.0                 2.0
# 910795                2.0              NaN            2.0                 1.0
#
#         activity_poultry  ...  grow_maize  grow_rice  grow_beans  num_cattle  \
# ...

# %%
# Select and rename useful columns
selected_columns = {
    "household_id": "Household ID",
    "state": "State",
    "lga": "LGA",
    "hh_head_sex": "Gender",
    "hh_head_age": "Age",
    "school_attendance": "School Attendance",
    "education_level": "Education Level",
    "activity_crop": "Crop Farming",
    "activity_livestock": "Livestock Farming",
    "activity_poultry": "Poultry Farming",
    "activity_fisheries": "Fisheries",
    "num_plots": "Number of Plots",
    "grow_maize": "Grows Maize",
    "grow_rice": "Grows Rice",
    "grow_beans": "Grows Beans",
    "num_cattle": "Number of Cattle",
    "num_goat": "Number of Goats",
    "num_chicken": "Number of Chickens",
    "fish_farming": "Fish Farming",
    "has_agri_establishment": "Agri Establishment",
    "has_nonagri_establishment": "Non-Agri Establishment",
    "weight": "Survey Weight"
}

df = df_filtered[list(selected_columns.keys())].rename(columns=selected_columns)
df.head()
# Out:
#         Household ID  State   LGA  Gender  Age  School Attendance  \
# 926732        966601    1.0  16.0     1.0  5.0                2.0
# 907051        189961    1.0  18.0     1.0  3.0                1.0
# 926516        130859    1.0  16.0     1.0  3.0                1.0
# 912760        655320    1.0   1.0     1.0  5.0                2.0
# 910795        440860    1.0   9.0     1.0  4.0                2.0
#
#         Education Level  Crop Farming  Livestock Farming  Poultry Farming  \
# 926732              NaN           2.0                2.0              2.0
# 907051              5.0           2.0                2.0              2.0
# 926516              6.0           2.0                2.0              2.0
# 912760              NaN           2.0                2.0              1.0
# 910795              NaN           2.0                1.0              1.0
#
#         ...  Grows Maize  Grows Rice  Grows Beans  Number of Cattle  \
# ...

# %%
df.to_csv('data.csv')
